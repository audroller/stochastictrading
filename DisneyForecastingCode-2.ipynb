# %%
#######
# Starter code for Time Series Analysis and Forecasting
#
# You will need to install the YahooFinance Python api
#
# Using Anaconda environment:
# - conda install -c conda-forge yfinance
#
# Using pip 
# - pip install yfinance
#
# Veryify it is installed by importing it in your Jupyter Notebook.
# If you cannot get it to install, you can always Google Search
# "install yfinance Python library"  and it will give you search results
# that walk you through.   As of 13-Nov-2024 both methods work.
#
# https://stackoverflow.com/questions/39636128/yahoo-finance-package-installation-in-anaconda
###

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp37-cp37m-macosx_10_9_x86_64.whl (652 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 652.7/652.7 kB 8.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=0.19 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (65.6.3)
# Requirement already satisfied: packaging>=17.1 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (22.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: numpy>=1.21.2 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: scipy>=1.3.2 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: urllib3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (1.26.14)
# Requirement already satisfied: joblib>=0.11 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pmdarima) (0.29.33)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sktime
# Out:
# Collecting sktime
#   Downloading sktime-0.19.2-py3-none-any.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 21.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from sktime) (22.0)
# Requirement already satisfied: numpy<1.25,>=1.21.0 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from sktime) (1.21.5)
# Requirement already satisfied: pandas<2.1.0,>=1.1.0 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from sktime) (1.3.5)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from sktime) (1.7.3)
# Collecting scikit-base<0.5.0
#   Downloading scikit_base-0.4.6-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.1/119.1 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn<1.3.0,>=0.24.0 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from sktime) (1.0.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from deprecated>=1.2.13->sktime) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pandas<2.1.0,>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pandas<2.1.0,>=1.1.0->sktime) (2022.7)
# Requirement already satisfied: joblib>=0.11 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (2.2.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas<2.1.0,>=1.1.0->sktime) (1.16.0)
# Installing collected packages: scikit-base, deprecated, sktime
# Successfully installed deprecated-1.2.15 scikit-base-0.4.6 sktime-0.19.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (0.13.5)
# Requirement already satisfied: pandas>=0.25 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: scipy<1.8,>=1.3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: packaging>=21.3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from statsmodels) (22.0)
# Requirement already satisfied: numpy>=1.17 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: patsy>=0.5.2 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from pandas>=0.25->statsmodels) (2022.7)
# Requirement already satisfied: six in /opt/miniconda3/envs/p3workshop/lib/python3.7/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime 
import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import numpy.matlib
import numpy.linalg

import yfinance as yf
import pandas as pd

from scipy.stats import zscore

from sklearn.preprocessing import StandardScaler

from sktime.split import temporal_train_test_split

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose 
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA

from pmdarima import auto_arima
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/nn/056zsw8j7jb1_55w7sz4q_yr0000gn/T/ipykernel_91334/489316208.py in <module>
#      14 from sklearn.preprocessing import StandardScaler
#      15
# ---> 16 from sktime.split import temporal_train_test_split
#      17
#      18 from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#
# ModuleNotFoundError: No module named 'sktime.split'

# %%
#####
# 40 years of data starting from when Disney got on the market
##
TRADE_START='1962-1-2'
TRADE_END='2002-1-2'

disneyTicker='DIS'

# %%
NUM_BINS= 20

# %%
disData= yf.download(disneyTicker, start=TRADE_START,end= TRADE_END)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
disData.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1962-01-02  0.092908  0.096026  0.092908  0.092908   0.057941   841958
# 1962-01-03  0.092908  0.094467  0.092908  0.094155   0.058719   801865
# 1962-01-04  0.094155  0.094467  0.093532  0.094155   0.058719   962238
# 1962-01-05  0.094155  0.094779  0.093844  0.094467   0.058914   962238
# 1962-01-08  0.094467  0.095714  0.092285  0.094155   0.058719  1282984

# %%
######
# To learn more, see multi-level columns in Pandas.
# They are kinda cool and make sense for complex aggregated data.
#
# https://pandas.pydata.org/docs/user_guide/advanced.html
#
# https://stackoverflow.com/questions/63107594/how-to-deal-with-multi-level-column-names-downloaded-with-yfinance
###
# df_dis_close = disData['Close'].DIS
df_dis_close = disData['Close']

# %%
df_dis_close.describe()
# Out:
# count    10069.000000
# mean         7.280632
# std         10.349134
# min          0.053625
# 25%          0.745013
# 50%          1.292212
# 75%         10.810396
# max         43.036064
# Name: Close, dtype: float64

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_dis_close.values.reshape(-1, 1)) 
scaled_series= pd.DataFrame(scaled_data)
scaled_series.plot()
# Out:
# <AxesSubplot:>

# %%
#####
#  Visualizations of various transformations
###

def visTransformations(df_data, dataName, windowSize):
    plt.figure(1,figsize=(30,90))
    plt.subplot(10,1,1)
    df_data.plot()
    plt.title(f'{dataName} closing price')
    
    plt.subplot(10,1,2)
    plt.title(f'{dataName} filtered outliers')
    z_scores = zscore(df_data)
    abs_z_scores = np.abs(z_scores)
    filtered_data = (abs_z_scores < 2)  # Z-score trheshold two standard deviations
    series_no_outliers = df_data[filtered_data]
    series_no_outliers.plot()

#    plt.subplot(9,1,3)
#    plt.title('{dataName} scaled and filtered')
#    scaler = StandardScaler()
#    scaled_data = scaler.fit_transform(series_no_outliers.values.reshape(-1, 1)) 
#    scaled_series= pd.DataFrame(scaled_data)
#    scaled_series.plot()

    plt.subplot(10,1,3)
    binCountsDIS, binEdgesDIS, patchesDIS= plt.hist(df_data,NUM_BINS)
    plt.title(f'{dataName} stock distribution')
    
    # long vs short term trend depends on window size
    plt.subplot(10,1,4)
    plt.title(f'{dataName} rolling average win=%i' %windowSize )
    df_dis_close.rolling(windowSize).mean().plot()
    
    # std dev over rolling window
    # shows how variance changes over time
    plt.subplot(10,1,5)
    plt.title(f'{dataName} rolling std win=%i'%windowSize)
    df_data.rolling(windowSize).std().plot()
    
    # can think of it like the local slope
    plt.subplot(10,1,6)
    plt.title(f'{dataName} difference 1x')
    df_data.diff().plot()

    DIFF_ORDER= 10
    plt.subplot(10,1,7)
    plt.title(f'{dataName} difference {DIFF_ORDER}x')
    df_diff= df_data
    for i in range(DIFF_ORDER):
        df_diff= df_diff.diff()
        
    df_diff.plot()

    # computes rolling window mean over difference
    # can i really remove the trend?
    plt.subplot(10,1,8)
    plt.title(f'{dataName} mean diff win=%i' %windowSize)
    df_data.diff().rolling(windowSize).mean().plot()
    
    plt.subplot(10,1,9)
    plt.title(f'{dataName} std diff win=%i' %windowSize)
    df_data.diff().rolling(windowSize).std().plot()

    # standard scaler 
    plt.subplot(10,1,10)
    plt.title(f'{dataName} scaled and filtered')
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(series_no_outliers.values.reshape(-1, 1)) 
    plt.plot(scaled_data)

# %%
##############
# Augmented Dickey-Fuller Test
#
# Ho: It is non-stationary
# H1: It is stationary
#
#####

def adfuller_test(sales):
    result=adfuller(sales)
    print(result)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

# %%
visTransformations(df_dis_close,'Disney Stock',20)

# %%
# def visTransformationsEWMA(df_data, dataName, windowSize):
#    plt.subplot(1, 1, 1)
#    plt.title(f'{dataName} exponential weighted moving average')
#    df_dis_close.ewm(windowSize).mean().plot()

# %%
# visTransformationsEWMA(df_dis_close,'Disney Stock',20)

# %%
def vis(df_data, dataName, windowSize):
    plt.figure(1,figsize=(30,40))
    
    plt.subplot(4, 1, 1)
    df_data.plot()
    plt.title(f'{dataName} closing price')
    
    plt.subplot(4, 1, 2)
    plt.title(f'{dataName} simple moving average')
    df_dis_close.rolling(windowSize).mean().plot()
    
    plt.subplot(4, 1, 3)
    plt.title(f'{dataName} exponential weighted moving average')
    df_dis_close.ewm(windowSize).mean().plot()
    
    plt.subplot(4, 1, 4)
    plt.title(f'{dataName} closing price and averages compared')
    df_data.plot()
    df_dis_close.rolling(windowSize).mean().plot()  
    df_dis_close.ewm(windowSize).mean().plot()

# %%
vis(df_dis_close,'Disney Stock',20)

# %%
# visTransformations(df_nvidia_close,'NVIDIA Stock',20)

# %%
df_dis_close.size
# Out:
# 10069

# %%
plt.figure(3,figsize=(30,10))
fig, ax = plt.subplots(figsize=(30, 10))
ax.set_xlabel('lag')
pltOutput= plot_acf(df_dis_close, lags=100, title='DIS Autocorrelation',alpha=0.05,ax=ax);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nn/056zsw8j7jb1_55w7sz4q_yr0000gn/T/ipykernel_91334/2999879982.py in <module>
#       2 fig, ax = plt.subplots(figsize=(30, 10))
#       3 ax.set_xlabel('lag')
# ----> 4 pltOutput= plot_acf(df_dis_close, lags=100, title='DIS Autocorrelation',alpha=0.05,ax=ax);
#
# NameError: name 'plot_acf' is not defined

# %%
plt.figure(4,figsize=(30,10))
fig, ax = plt.subplots(figsize=(30, 10))
ax.set_xlabel('lag')
pltOutput= plot_pacf(df_dis_close, lags=5, title='DIS Partial Autocorrelation',alpha=0.05,ax=ax);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nn/056zsw8j7jb1_55w7sz4q_yr0000gn/T/ipykernel_91334/3935860177.py in <module>
#       2 fig, ax = plt.subplots(figsize=(30, 10))
#       3 ax.set_xlabel('lag')
# ----> 4 pltOutput= plot_pacf(df_dis_close, lags=5, title='DIS Partial Autocorrelation',alpha=0.05,ax=ax);
#
# NameError: name 'plot_pacf' is not defined

# %%
DAYS_PER_QUARTER= 63
result= seasonal_decompose(df_dis_close,model='multiplicative',period=DAYS_PER_QUARTER)
o= result.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nn/056zsw8j7jb1_55w7sz4q_yr0000gn/T/ipykernel_91334/360862294.py in <module>
#       1 DAYS_PER_QUARTER= 63
# ----> 2 result= seasonal_decompose(df_dis_close,model='multiplicative',period=DAYS_PER_QUARTER)
#       3 o= result.plot()
#
# NameError: name 'seasonal_decompose' is not defined

# %%
####
# Run the augmented Dickey-Fuller Test
###
adfuller_test(df_dis_close)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nn/056zsw8j7jb1_55w7sz4q_yr0000gn/T/ipykernel_91334/1790819534.py in <module>
#       2 # Run the augmented Dickey-Fuller Test
#       3 ###
# ----> 4 adfuller_test(df_dis_close)
#
# /var/folders/nn/056zsw8j7jb1_55w7sz4q_yr0000gn/T/ipykernel_91334/1752810063.py in adfuller_test(sales)
#       8
#       9 def adfuller_test(sales):
# ---> 10     result=adfuller(sales)
#      11     print(result)
#      12     labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
#
# NameError: name 'adfuller' is not defined

# %%
#######
#  Tools are in place in Python to experiment with ARIMA and
#  propose the parameters (p,d,q)
####

DO_IT= False

if (DO_IT):
    stepwise_fit = auto_arima(df_dis_close, start_p = 1, start_q = 1, 
                              max_p = 3, max_q = 3, m = 12, 
                              start_P = 0, seasonal = True, 
                              d = None, D = 1, trace = True, 
                              error_action ='ignore',   # we don't want to know if an order does not work 
                              suppress_warnings = True,  # we don't want convergence warnings 
                              stepwise = True)           # set to stepwis

    stepwise_fit.summary()

# %%
####### 
#  Fit the SARIMAX model
#
#  SARIMAX( nonseasonal, seasonal)
#
#  nonseasonaly= (p,d,q)
#
#  p: regression window size
#  d: differencing order
#  q: moving average (prediction error window)
#
#  seasonal=  (P,D,Q, m)
#
#  P: regression window size
#  D: differencing order
#  Q: moving average (prediction error window)
#
###

model = SARIMAX(df_dis_close,  
                order = (2,1,1),  
                seasonal_order =(4, 1, 1, 20)) 
  
result = model.fit() 
result.summary()
# Out:
# C:\Users\Audrey\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Audrey\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
df_dis_close.size

# %%
#######
# New index from Date Time
#
# Utility routine to fix issue with yfinance DateTime index
###
def computeDateList(startDate, numDays):
    dateList = []
    for x in range (0, numDays):
        dt= startDate + datetime.timedelta(days= x)
    
        dateList.append(dt.strftime('%Y-%m-%d %H:%M:%S'))
        
    return dateList

# %%
origStartDate= datetime.datetime(2019,12,4)

forecastStartDate= datetime.datetime(2024,12,5)

HIST_DAYS= df_dis_close.size

NUM_DAYS= 252

disDateIndex= computeDateList(origStartDate,HIST_DAYS)

forecastDateIndex= computeDateList(forecastStartDate, NUM_DAYS)

# %%
#######
# Use SARIMA model to do the forecast
# 
# Tinker with Series objects to properly set the index to good datetime format
####

ONE_QUARTER= 63 * 1
TWO_QUARTER= 63 * 2
THREE_QUARTER= 63 *3
FOUR_QUARTER= 64* 4

forecastHorizon= FOUR_QUARTER

####
# do the forecast over time horizon (future days)
##
forecast= result.forecast(steps=forecastHorizon)

#myForecast= pd.Series(forecast.values, index=forecastDateIndex)

####
# do prediction over existing time series
##
predictions= result.predict()

####
# set Series index to proper datetime formatted strings
##
myPredictions= pd.Series(predictions.values, index= disDateIndex)

myDISClose= pd.Series(df_dis_close.values, index= disDateIndex)

####
# Visualize
###
plt.figure(12,figsize=(20,15))
plt.subplot(2,1,1)
myDISClose.plot(color='blue',label='actual')
myPredictions.plot(color='red',label='predictions')
forecast.plot(color='green',label='forecast')
plt.legend()
plt.title(f'SARIMA forecast horizon= {forecastHorizon} steps')

# %%
plt.figure(5,figsize=(30,10))
fig, ax = plt.subplots(figsize=(30, 10))
ax.set_xlabel('lag')
pltOutput= plot_acf(df_dis_close, lags=100, title='DIS Autocorrelation',alpha=0.05,ax=ax);

# %%
plt.figure(6,figsize=(30,10))
fig, ax = plt.subplots(figsize=(30, 10))
ax.set_xlabel('lag')
pltOutput= plot_pacf(df_dis_close, lags=5, title='DIS Partial Autocorrelation',alpha=0.05,ax=ax);

# %%
######
# Break time-series into it's constituent parts
#
# - level
# - trend
# - seasonality
# - noise
#
#  x(t) = Level + Trend + Seasonality + Noise
##
DAYS_PER_QUARTER= 63
result= seasonal_decompose(df_dis_close,model='multiplicative',period=DAYS_PER_QUARTER)
o= result.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nn/056zsw8j7jb1_55w7sz4q_yr0000gn/T/ipykernel_91334/783781442.py in <module>
#      10 ##
#      11 DAYS_PER_QUARTER= 63
# ---> 12 result= seasonal_decompose(df_dis_close,model='multiplicative',period=DAYS_PER_QUARTER)
#      13 o= result.plot()
#
# NameError: name 'seasonal_decompose' is not defined

# %%
test_result=adfuller_test(df_dis_close)
test_result
